# %%
# Q1. What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use
# MongoDB over SQL databases?

# ans 1:-

'''
MongoDB is an open-source, document-oriented database that stores data in collections and documents.
It’s a NoSQL (Not only SQL) database because the storage and retrieval of data in MongoDB are not in the form of tables.
MongoDB uses BSON (Binary representation of JSON documents) for data storage, which allows for efficient querying and storag

Non-relational databases, also known as NoSQL databases, store data in a non-tabular form,
making them more flexible than traditional SQL-based relational database structures.
They might be based on data structures like documents. 
Non-relational databases are ideal for handling large volumes of complex and diverse data and are highly efficient in
distributed environments. There are four main types of non-relational databases: key/value, graph, column, and document.


MongoDB is often preferred over SQL databases in the following scenarios:

When you need to work with large scale data and require high performance.
When your data does not have a fixed schema or is unstructured.
When you need to build highly available and scalable internet applications.
When you need high insert rate over transaction safety.
When you need high availability in an unreliable environment.
When your system fulfills the prerequisites and optimized querying is desired.
'''

# %%
# Q2. State and Explain the features of MongoDB.

# ans 2:-

'''
Document Model: MongoDB is a document-oriented database, which means that data is stored as documents,
and documents are grouped in collections. The document model is more natural for developers to work with because
documents are self-contained and can be treated as objects. This allows developers to focus on the data they need to store and process,
rather than worrying about how to split the data across different rigid tables.

Flexible Schema: Documents in a single collection don’t necessarily need to have exactly the same set of fields.
This flexibility allows developers to iterate faster and migrate data between different schemas without any downtime.
However, if you want to lock down your schema at a certain point, you can do so by applying validation rules to your collections.

BSON Format: Documents in MongoDB are stored in the BSON format, which is a binary-encoded JSON format.
This allows for the storage of binary data, which is useful for storing images, videos, and other binary data.
Even though BSON is a binary-encoded format, it’s easy to work with it using the MongoDB driver for your programming language.

Sharding: Sharding is the process of splitting larger datasets across multiple distributed instances, or “shards”.
When applied to particularly large datasets, sharding helps the database distribute and
better execute what might otherwise be problematic and cumbersome queries.

Replication: MongoDB provides high availability with replica sets.
A replica set consists of two or more copies of the data.
Each replica set member may act in the role of primary or secondary replica at any time.

Indexing: Indexes support the efficient execution of queries in MongoDB.
Without indexes, MongoDB must perform a collection scan, i.e., scan every document in a collection,
to select those documents that match the query statement.

Load Balancing: MongoDB uses sharding to provide horizontal scalability. This is done by distributing data across many servers.

Support for Multiple Storage Engines: MongoDB supports multiple storage engines, such as WiredTiger and MMAPv.

Aggregation Framework: MongoDB provides an aggregation framework to perform grouped operations on the data, like SQL’s GROUP BY.

Text Search: MongoDB supports text search, making it easy to find documents that contain a specific word or phrase.

'''

# %%
# Q3. Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.

# ans 3:-

'''
pip install pymongo

import pymongo
client = pymongo.MongoClient("mongodb+srv://Shazan:pwskills@cluster0.auc38it.mongodb.net/?retryWrites=true&w=majority")
db = client.test

db = client['pwskills']

coll_pwskills = db["My_record"]

'''

# %%
# Q4. Using the database and the collection created in question number 3, write a code to insert one record,
# and insert many records. Use the find() and find_one() methods to print the inserted record.

# ans 4 :-

'''

pip install pymongo

import pymongo
client = pymongo.MongoClient("mongodb+srv://Shazan:pwskills@cluster0.auc38it.mongodb.net/?retryWrites=true&w=majority")
db = client.test

db = client['pwskills']

data = {"Name" : "Shazan Suria",
        "Class" : "Data Science Masters",
        "time" : "flex"
       }

coll_pwskills = db["My_record"]

coll_pwskills.insert_one(data)

data2= [{'_id' : '1','Name' : 'ABC'},
        {'_id' : '2','Name' : 'DEF'},
        {'_id' : '3','Name' : 'GHI'}
       ]
       
coll_pwskills.insert_many(data2)

coll_pwskills.find_one()

for i in coll_pwskills.find():
    print(i)
'''

# %%
# Q5. Explain how you can use the find() method to query the MongoDB database. Write a simple code to
# demonstrate this.

# ans 5:-

'''
The find() method in MongoDB is used to select documents in a collection and return a cursor to the selected documents.
The method uses a query document that you provide to match the subset of the documents in the collection that match the query.
If you don’t provide a query document (or if you provide an empty document), MongoDB returns all documents in the collection.

import pymongo

client = pymongo.MongoClient("mongodb+srv://Shazan:pwskills@cluster0.auc38it.mongodb.net/?retryWrites=true&w=majority")
db = client.test

db = client['pwskills']

coll_pwskills = db["My_record"]

for i in coll_pwskills.find():
    print(i)
'''

# %%
# Q6. Explain the sort() method. Give an example to demonstrate sorting in MongoDB.

# ans 6:-

'''
The sort() method in MongoDB is used to sort the documents in a collection based on the specified criteria.
It takes a document that defines the sorting order, where each field can be specified with a value of 1 (for ascending order)
or -1 (for descending order). If no value is specified, the default is ascending order (1).

Ex:- 

import pymongo

client = pymongo.MongoClient("mongodb+srv://Shazan:pwskills@cluster0.auc38it.mongodb.net/?retryWrites=true&w=majority")
db = client.test

db = client['pwskills']

demo_coll = db["samp"]

samp_data=[{ "name": "Alice", "age": 25 },
           { "name": "Bob", "age": 30 },
           { "name": "Charlie", "age": 20 }
          ]

demo_coll.insert_many(samp_data)

result = demo_coll.find().sort("age",1)

for i in result:
    print(i)
'''

# %%
# Q7. Explain why delete_one(), delete_many(), and drop() is used.

# ans 7:-

'''

The methods delete_one(), delete_many(), and drop() are used in MongoDB for different purposes related to removing data from a collection or dropping an entire collection altogether.

1.delete_one():-

    This method is used to delete a single document that matches the specified filter criteria.
    
    If there are multiple documents that match the filter, only the first one encountered will be deleted.
    
    It takes a filter parameter to specify which document(s) to delete.
    
    This method is useful when you want to remove a specific document from a collection without affecting other documents.
    
    Example: Deleting a specific document based on a unique identifier or some other criteria.
    
    
delete_many():-

    This method is used to delete multiple documents that match the specified filter criteria.
    
    It removes all documents that match the filter, not just the first one.
    
    Like delete_one(), it also takes a filter parameter to specify which document(s) to delete.
    
    This method is handy when you want to delete multiple documents that meet certain conditions.
    
    Example: Deleting all documents where a certain field has a specific value.
    
    
drop():

    This method is used to drop an entire collection from the database.
    
    Dropping a collection removes all documents within it and the collection itself from the database.
    
    It does not take any parameters; you simply call it on the collection object.
    
    This method is typically used when you want to completely remove a collection and all its data,
    for example, when you no longer need the data or want to start fresh.
    
    Caution should be exercised when using drop() as it irreversibly deletes all data in the collection.
    
    Example: Dropping a collection after it is no longer needed or as part of a database cleanup process.
'''
